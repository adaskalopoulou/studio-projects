# %%
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv("sdna0108.csv")
df1
# Out:
#                          Bureau of Justice Statistics Unnamed: 1  Unnamed: 2  \
# 0                              Filename: sdna0108.csv        NaN         NaN
# 1   Table 8.  Status of case workloads in DNA crim...        NaN         NaN
# 2   Title of Report:  Survey of DNA Crime Laborato...        NaN         NaN
# 3   Data source:  National Survey of DNA Laborator...        NaN         NaN
# 4                              Author:  Greg Steadman        NaN         NaN
# 5   Refer questions to: (202) 307-0765 or askbjs@o...        NaN         NaN
# 6                             Date version:  01/31/02        NaN         NaN
# 7                                                 NaN        NaN         NaN
# 8   Table 8.  Status of case workloads in DNA crim...        NaN         NaN
# 9                                                 NaN        NaN         NaN
# 10                                                NaN       Labs         NaN
# ...
