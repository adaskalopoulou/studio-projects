# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] =42
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches

# %%
df = pd.read_excel("publicspreadsheet.xlsx")
pd.set_option("display.max_columns", 100)
df
# Out:
#           Last Name       First Name   Age       Race     Sex  \
# 0            Abbitt    Joseph Lamont  31.0      Black    Male
# 1             Abdal     Warith Habib  43.0      Black    Male
# 2         Abernathy      Christopher  17.0  Caucasian    Male
# 3             Acero          Longino  35.0   Hispanic    Male
# 4             Adams          Anthony  26.0   Hispanic    Male
# 5             Adams           Cheryl  26.0  Caucasian  Female
# 6             Adams          Darryl   25.0      Black    Male
# 7             Adams          Don Ray  32.0      Black    Male
# 8             Adams       Jarrett M.  17.0      Black    Male
# 9             Adams        Johnathan  12.0  Caucasian    Male
# 10            Adams           Johnny  52.0      Black    Male
# 11            Adams          Kenneth  21.0      Black    Male
# 12            Adams         Laurence  19.0      Black    Male
# 13            Adams     Randall Dale  28.0  Caucasian    Male
# ...

# %%
df.dtypes
# Out:
# Last Name                           object
# First Name                          object
# Age                                float64
# Race                                object
# Sex                                 object
# State                               object
# County                              object
# Tags                                object
# Worst Crime Display                 object
# List Add'l Crimes Recode            object
# Occurred                             int64
# Convicted                            int64
# Exonerated                           int64
# Sentence                            object
# DNA                                 object
# *                                   object
# FC                                  object
# MWID                                object
# F/MFE                               object
# P/FA                                object
# OM                                  object
# ILD                                 object
# ...

# %%
df['Years_lost'] = df.Exonerated - df.Convicted
df
# Out:
#           Last Name       First Name   Age       Race     Sex  \
# 0            Abbitt    Joseph Lamont  31.0      Black    Male
# 1             Abdal     Warith Habib  43.0      Black    Male
# 2         Abernathy      Christopher  17.0  Caucasian    Male
# 3             Acero          Longino  35.0   Hispanic    Male
# 4             Adams          Anthony  26.0   Hispanic    Male
# 5             Adams           Cheryl  26.0  Caucasian  Female
# 6             Adams          Darryl   25.0      Black    Male
# 7             Adams          Don Ray  32.0      Black    Male
# 8             Adams       Jarrett M.  17.0      Black    Male
# 9             Adams        Johnathan  12.0  Caucasian    Male
# 10            Adams           Johnny  52.0      Black    Male
# 11            Adams          Kenneth  21.0      Black    Male
# 12            Adams         Laurence  19.0      Black    Male
# 13            Adams     Randall Dale  28.0  Caucasian    Male
# ...

# %%
df.shape
# Out:
# (2060, 24)

# %%
df['DNA'].value_counts()
# Out:
# DNA    449
# Name: DNA, dtype: int64

# %%
DNA = df[df['DNA']=='DNA']
DNA.shape
# Out:
# (449, 24)

# %%
DNA.head()
# Out:
#     Last Name     First Name   Age       Race   Sex           State   County  \
# 0      Abbitt  Joseph Lamont  31.0      Black  Male  North Carolina  Forsyth
# 1       Abdal   Warith Habib  43.0      Black  Male        New York     Erie
# 2   Abernathy    Christopher  17.0  Caucasian  Male        Illinois     Cook
# 6       Adams        Darryl   25.0      Black  Male           Texas   Dallas
# 11      Adams        Kenneth  21.0      Black  Male        Illinois     Cook
#
#           Tags Worst Crime Display  \
# 0           CV     Child Sex Abuse
# 1          NaN      Sexual Assault
# 2   CIU;#CV;#H              Murder
# 6   CIU;#NC;#P      Sexual Assault
# 11  CDC;#H;#JI              Murder
#
#                              List Add'l Crimes Recode  Occurred  Convicted  \
# 0   Sexual Assault;#Kidnapping;#Burglary/Unlawful ...      1991       1995
# 1                                             Robbery      1982       1983
# ...

# %%
DNA['Full Name'] = DNA['First Name'] + " " + DNA['Last Name']
DNA
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           Last Name       First Name   Age       Race     Sex  \
# 0            Abbitt    Joseph Lamont  31.0      Black    Male
# 1             Abdal     Warith Habib  43.0      Black    Male
# 2         Abernathy      Christopher  17.0  Caucasian    Male
# 6             Adams          Darryl   25.0      Black    Male
# 11            Adams          Kenneth  21.0      Black    Male
# 27        Alejandro          Gilbert  35.0   Hispanic    Male
# 29        Alexander          Richard  29.0      Black    Male
# 34            Allen          Donovan  18.0  Caucasian    Male
# ...

# %%
df_full = DNA.merge(df_in_proj, left_on='Full Name', right_on='name', how='outer')
df_full.head(1)
# Out:
#   Last Name     First Name   Age   Race   Sex           State   County Tags  \
# 0    Abbitt  Joseph Lamont  31.0  Black  Male  North Carolina  Forsyth   CV
#
#   Worst Crime Display                           List Add'l Crimes Recode  \
# 0     Child Sex Abuse  Sexual Assault;#Kidnapping;#Burglary/Unlawful ...
#
#    Occurred  Convicted  Exonerated Sentence  DNA    *   FC  MWID F/MFE P/FA  \
# 0      1991       1995        2009     Life  DNA  NaN  NaN  MWID   NaN  NaN
#
#     OM  ILD Posting Date  Years_lost             Full Name name  \
# 0  NaN  NaN   2011-09-01          14  Joseph Lamont Abbitt  NaN
#
#   science_problem
# 0             NaN

# %%
df_in_proj = pd.read_csv("In_project_test.csv")
df_in_proj
# Out:
#                 name science_problem
# 0  Gilbert Alejandro             DNA
# 1       Gene Bibbins             DNA
# 2     Stephan Cowans             DNA
# 3     Timothy Durham             DNA
# 4         Chad Heins             DNA
# 5       Dana Holland             DNA
# 6     Dwayne Jackson             DNA
# 7   Marlon Pendleton             DNA
# 8     Anthony Powell             DNA
# 9      Josiah Sutton             DNA

# %%
df_proDNA = DNA.merge(df_in_proj, left_on='Full Name', right_on='name')
df_proDNA
# Out:
#     Last Name First Name   Age       Race   Sex          State     County  \
# 0   Alejandro    Gilbert  35.0   Hispanic  Male          Texas     Uvalde
# 1     Bibbins       Gene  29.0      Black  Male      Louisiana  LA Parish
# 2      Cowans    Stephan  26.0      Black  Male  Massachusetts    Suffolk
# 3      Durham    Timothy  28.0  Caucasian  Male       Oklahoma      Tulsa
# 4       Heins       Chad  18.0  Caucasian  Male        Florida      Duval
# 5     Holland       Dana  25.0      Black  Male       Illinois       Cook
# 6     Holland       Dana  25.0      Black  Male       Illinois       Cook
# 7     Jackson     Dwayne  18.0      Black  Male         Nevada      Clark
# 8   Pendleton     Marlon  35.0      Black  Male       Illinois       Cook
# 9      Powell    Anthony  23.0      Black  Male  Massachusetts    Suffolk
# 10     Sutton     Josiah  16.0      Black  Male          Texas     Harris
#
#      Tags Worst Crime Display                List Add'l Crimes Recode  \
# ...

# %% [markdown]
# # Dates

# %%
DNA.groupby('Convicted')['Convicted'].value_counts().plot(kind='bar', figsize=(10,10))

# ['Exonerated'].value_counts()
# dates.groupby(level=0).nlargest(1).sort_values(ascending=False)

# %%
DNA.groupby('Exonerated')['Exonerated'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = DNA['Exonerated'].value_counts().sort_index().plot(kind='line', figsize=(18,10), linewidth=5, color='#CE976D')
df_proDNA['Convicted'].value_counts().sort_index().plot(kind='line', figsize=(18,10), linewidth=5, color='#7585A4', ax=ax)

yellow_patch = mpatches.Patch(color='#CE976D', label='Cases exonerated using DNA')
blue_patch = mpatches.Patch(color='#7585A4', label='People convicted for crimes they did not commit based on DNA evidence')
plt.legend(handles=[yellow_patch, blue_patch])


ax.set_title("Number of cases between 1986-2016")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.set_xlabel('Date')
ax.set_ylabel('Number of cases')

# resample

# %%
ax = DNA['Exonerated'].value_counts().sort_index().plot(kind='barh', figsize=(10,7), linewidth=5, color='#CE976D')
df_proDNA['Convicted'].value_counts().sort_index().plot(kind='barh', figsize=(10,7), linewidth=5, color='#7585A4', ax=ax)

yellow_patch = mpatches.Patch(color='#CE976D', label='Cases exonerated using DNA')
blue_patch = mpatches.Patch(color='#7585A4', label='People convicted for crimes they did not commit based on DNA evidence')
plt.legend(handles=[yellow_patch, blue_patch])


ax.set_title("Number of cases between 1986-2016")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.set_xlabel('Date')
ax.set_ylabel('Number of cases')

plt.savefig("boring-graph1.pdf")

# %%
ax = DNA['Exonerated'].value_counts().sort_index().plot(kind='barh', figsize=(10,20), linewidth=5, color='#CE976D')

yellow_patch = mpatches.Patch(color='#CE976D', label='Cases exonerated using DNA')
blue_patch = mpatches.Patch(color='#7585A4', label='People convicted for crimes they did not commit based on DNA evidence')
plt.legend(handles=[yellow_patch, blue_patch])


ax.set_title("Number of cases between 1986-2016")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.set_xlabel('Date')
ax.set_ylabel('Number of cases')

# resample
plt.savefig("boring-graph2.pdf")

# %% [markdown]
# # Sentence

# %%
DNA.Sentence.value_counts().head()
# Out:
# Life                   127
# Life without parole     30
# Death                   25
# 30 years                17
# 40 years                15
# Name: Sentence, dtype: int64

# %%
# Data to plot
labels = 'Life', 'Life without parole', 'Death', '30 years', '40 years'
sizes = [127, 30, 25, 17, 15]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D', '#82491D']
explode = (0, 0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('DNA-based exonerations saved people who were convicted')
plt.axis('equal')
plt.show()

# %%
df.Sentence.value_counts().head()
# Out:
# Life                   364
# Death                  117
# Life without parole    109
# Not sentenced           98
# Probation               89
# Name: Sentence, dtype: int64

# %%
# Data to plot
labels = 'Life', 'Death', 'Life without parole', 'Not sentenced', 'Probation'
sizes = [364, 117, 109, 98, 89]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D', '#82491D']
explode = (0, 0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('All exonerations saved people who were convicted')
plt.axis('equal')
plt.show()

# %%
df_proDNA.Sentence.value_counts().head()
# Out:
# Life              3
# 30 to 45 years    1
# 20 years          1
# 12 to 20 years    1
# 28 years          1
# Name: Sentence, dtype: int64

# %%
# Data to plot
labels = 'Life', '4 years', '25 years', '90 years', '12 to 20 years'
sizes = [3, 1, 1, 1, 1]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D', '#82491D']
explode = (0, 0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('DNA-exonerations of DNA-problematic cases saved people who were convicted')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Years lost

# %%
df.shape
# Out:
# (2060, 24)

# %%
DNA.shape
# Out:
# (449, 25)

# %% [markdown]
# 2060 cases --> 21619 years ///
# 449 cases ---> x = 4712 years lost DNA, will true: 7193

# %%
df.Years_lost.sum()
# Out:
# 21619

# %%
DNA.Years_lost.sum()
# Out:
# 7193

# %%
df.Years_lost.mean()
# Out:
# 10.494660194174758

# %%
DNA.Years_lost.mean()
# Out:
# 16.020044543429844

# %% [markdown]
# # Crimes committed

# %% [markdown]
# False Confession (FC)—A confession is a statement made to law enforcement at any point during the proceedings which was interpreted or presented by law enforcement as an admission of participation in or presence at the crime, even if the statement was not presented at trial. A statement is not a confession if it was made to someone other than law enforcement. A statement that is not at odds with the defense is not a confession. A guilty plea is not a confession.

# %%
DNA.FC.value_counts()
# Out:
# FC    99
# Name: FC, dtype: int64

# %%
(DNA.FC.value_counts()) / (df.FC.value_counts())
# Out:
# FC    0.407407
# Name: FC, dtype: float64

# %% [markdown]
# ### Mistaken Witness Identification (MWID)—At least one witness mistakenly identified the exoneree as a person the witness saw commit the crime.

# %%
DNA.MWID.value_counts()
# Out:
# MWID    264
# Name: MWID, dtype: int64

# %%
# this means that in the cases that dna solved the crime, the problem was with a human making a wrong assumption

# %% [markdown]
# False or Misleading Forensic Evidence (F/MFE)—Exoneree's conviction was based at least in part on forensic information that was (1) caused by errors in forensic testing, (2) based on unreliable or unproven methods, (3) expressed with exaggerated and misleading confidence, or (4) fraudulent.

# %%
DNA['F/MFE'].value_counts().head()
# Out:
# F/MFE    178
# Name: F/MFE, dtype: int64

# %% [markdown]
# Perjury or False Accusation (P/FA)—A person other than the exoneree committed perjury by making a false statement under oath that incriminated the exoneree in the crime for which the exoneree was later exonerated, or made a similar unsworn statement that would have been perjury if made under oath.

# %%
DNA['P/FA'].value_counts()
# Out:
# P/FA    198
# Name: P/FA, dtype: int64

# %% [markdown]
# Official Misconduct (OM)—Police, prosecutors, or other government officials significantly abused their authority or the judicial process in a manner that contributed to the exoneree's conviction.

# %%
DNA.OM.value_counts()
# Out:
# OM    215
# Name: OM, dtype: int64

# %% [markdown]
# Inadequate Legal Defense (ILD)—The exonoree's lawyer at trial provided obviously and grossly
# inadequate representation.

# %%
DNA.ILD.value_counts()
# Out:
# ILD    51
# Name: ILD, dtype: int64

# %%
labels = 'Mistaken Witness Identification', 'False or Misleading Forensic Evidence', 'Perjury or False Accusation', 'Official Misconduct', 'Inadequate Legal Defense'
sizes = [264, 178, 198, 215, 51]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D', '#82491D']
explode = (0, 0, 0, 0, 0)  # explode 1st slice
fig=plt.figure(figsize=(10,10)) 
ax=fig.add_subplot(1,1,1)
# Plot
ax.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
ax.set_title('Reason behind first conviction that lead to DNA-based exoneration')
ax.axis('equal')
plt.show()

# %% [markdown]
# ## worst crime test

# %%
DNA['Worst Crime Display'].value_counts().head()
# Out:
# Sexual Assault      203
# Murder              182
# Child Sex Abuse      31
# Robbery              14
# Attempted Murder      5
# Name: Worst Crime Display, dtype: int64

# %%
DNA['Worst Crime Display'].value_counts().plot(kind='barh')

# %%
df_proDNA['Convicted'].value_counts()
# Out:
# 1996    2
# 2003    1
# 1998    1
# 1997    1
# 1995    1
# 1993    1
# 1992    1
# 1990    1
# 1987    1
# 1999    1
# Name: Convicted, dtype: int64

# %%
df_proDNA['Exonerated'].value_counts()
# Out:
# 2004    3
# 2003    3
# 1997    1
# 2011    1
# 1994    1
# 2007    1
# 2006    1
# Name: Exonerated, dtype: int64

# %% [markdown]
# ## --> most of them during the period of the DNA labs survey

# %%
df_full['science_problem'].value_counts()
# Out:
# DNA    11
# Name: science_problem, dtype: int64

# %%
df_full.groupby('science_problem')['MWID'].count()
# Out:
# science_problem
# DNA    8
# Name: MWID, dtype: int64

# %%
df_full.groupby('science_problem')['F/MFE'].count()
# Out:
# science_problem
# DNA    9
# Name: F/MFE, dtype: int64

# %%
df_full.groupby('science_problem')['P/FA'].count()
# Out:
# science_problem
# DNA    7
# Name: P/FA, dtype: int64

# %%
df_full.groupby('science_problem')['OM'].count()
# Out:
# science_problem
# DNA    7
# Name: OM, dtype: int64

# %%
df_full.groupby('science_problem')['ILD'].count()
# Out:
# science_problem
# DNA    0
# Name: ILD, dtype: int64

# %%
df_full.groupby('science_problem')['Exonerated'].count()
# Out:
# science_problem
# DNA    11
# Name: Exonerated, dtype: int64

# %%
 
# Data to plot
labels = 'Mistaken Witness Identification', 'False or Misleading Forensic Evidence', 'Perjury or False Accusation', 'Official Misconduct'
sizes = [8, 9, 7, 7]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D']
explode = (0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Reason behind first conviction that lead to 2 DNA exonerations')
plt.axis('equal')
plt.show()

# %%
# Data to plot
labels = 'Mistaken Witness Identification', 'False or Misleading Forensic Evidence', 'Perjury or False Accusation', 'Official Misconduct'
sizes = [8, 9, 7, 7]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D']
explode = (0, 0, 0, 0)  # explode 1st slice
fig=plt.figure(figsize=(10,10)) 
ax=fig.add_subplot(1,1,1)
# Plot
ax.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
ax.set_title('Reason behind first conviction that lead to 2 DNA exonerations')
ax.axis('equal')
plt.show()

# %% [markdown]
# Mistaken Witness Identification(MWID) -
# False or Misleading Forensic Evidence(F/MFE) -
# Perjury or False Accusation(P/FA) -
# Official Misconduct(OM) -

# %% [markdown]
# # State

# %%
DNA['State'].value_counts()
# Out:
# Texas                   59
# Illinois                56
# New York                40
# California              22
# North Carolina          21
# Virginia                18
# Florida                 17
# Louisiana               15
# Pennsylvania            15
# Missouri                14
# Wisconsin               13
# Ohio                    13
# Oklahoma                12
# Massachusetts           11
# Indiana                 11
# Georgia                 10
# New Jersey               9
# Michigan                 7
# Maryland                 7
# Nebraska                 6
# Mississippi              6
# Connecticut              6
# District of Columbia     6
# West Virginia            6
# Tennessee                5
# Washington               5
# Arizona                  3
# Alabama                  3
# Colorado                 3
# Kentucky                 3
# Kansas                   3
# Oregon                   3
# Puerto Rico              3
# Utah                     3
# ...

# %% [markdown]
# # Age

# %%
df_full.groupby('science_problem')['Age'].value_counts()
# Out:
# science_problem  Age
# DNA              18.0    2
#                  25.0    2
#                  35.0    2
#                  16.0    1
#                  23.0    1
#                  26.0    1
#                  28.0    1
#                  29.0    1
# Name: Age, dtype: int64

# %%
DNA['Age'].value_counts().sort_index().plot(kind='bar', figsize=(10,10), color ='#437F7B')

# %%
bins = [13, 18, 22, 26, 30, 34, 38, 42, 46, 50, 54, 58, 62, 66]
group_names = ['14-18', '19-22', '23-26', '27-30', '31-34', '35-38', '39-42', '43-46', '47-50', '51-54', '55-58', '59-62', '63-66']
#includes the number on the right and not on the left
DNA['age_groups'] = pd.cut(df['Age'], bins, labels=group_names)
DNA['age_groups'].value_counts().sort_index().plot(kind='bar', figsize=(10,10), color ='#437F7B')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
ax= DNA['age_groups'].value_counts().sort_index().plot(kind='bar', figsize=(10,10), color ='#437F7B')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.set_xlabel('Age')
ax.set_ylabel('Number of exonerated cases')
ax.set_title("Age of people exonerated based on DNA evidence")

# %% [markdown]
# # RACE

# %%
df_full.groupby('science_problem')['Race'].value_counts()
# Out:
# science_problem  Race
# DNA              Black        8
#                  Caucasian    2
#                  Hispanic     1
# Name: Race, dtype: int64

# %%
df['Race'].value_counts()
# Out:
# Black                  962
# Caucasian              803
# Hispanic               248
# Asian                   19
# Native American         14
# Other                   13
# Hispanic;#Caucasian      1
# Name: Race, dtype: int64

# %%
df['Race'].value_counts() *100 / len(df.Race)
# Out:
# Black                  46.699029
# Caucasian              38.980583
# Hispanic               12.038835
# Asian                   0.922330
# Native American         0.679612
# Other                   0.631068
# Hispanic;#Caucasian     0.048544
# Name: Race, dtype: float64

# %%
DNA['Race'].value_counts()
# Out:
# Black              266
# Caucasian          144
# Hispanic            35
# Native American      2
# Other                1
# Asian                1
# Name: Race, dtype: int64

# %%
DNA['Race'].value_counts()*100 / len(DNA.Race)
# Out:
# Black              59.242762
# Caucasian          32.071269
# Hispanic            7.795100
# Native American     0.445434
# Other               0.222717
# Asian               0.222717
# Name: Race, dtype: float64

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Black', 'Caucasian', 'Hispanic', 'other'
sizes = [266, 144, 35, 4]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D']
explode = (0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Race of people involved in DNA-based exoneration cases')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Black', 'Caucasian', 'Hispanic', 'other'
sizes = [46.699029, 38.980583, 12.038835, 2.2815540000000003]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D']
explode = (0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Race of people involved in all exoneration cases')
plt.axis('equal')
plt.show()

# %%
df_proDNA['Race'].value_counts()*100 / len(df_proDNA.Race)
# Out:
# Black        72.727273
# Caucasian    18.181818
# Hispanic      9.090909
# Name: Race, dtype: float64

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Black', 'Caucasian', 'Hispanic'
sizes = [72.727273, 18.181818, 9.090909]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D']
explode = (0.1, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Race of exonerated people involved in cases with DNA problem')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Worst crime

# %% [markdown]
# ### DNA cases

# %%
DNA['Worst Crime Display'].value_counts().head(5)
# Out:
# Sexual Assault      203
# Murder              182
# Child Sex Abuse      31
# Robbery              14
# Attempted Murder      5
# Name: Worst Crime Display, dtype: int64

# %%
DNA['Worst Crime Display'].value_counts().sum() - DNA['Worst Crime Display'].value_counts().head(5).sum()
# Out:
# 14

# %%
DNA['Worst Crime Display'].value_counts().sort_values(ascending=True).tail(5).plot(kind='barh')

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Sexual Assault', 'Murder', 'Child Sex Abuse', 'Robbery', 'Kidnapping', 'other'
sizes = [203, 182, 31, 14, 5, 14]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D', '#82491D', '#7585A4']
explode = (0.1, 0, 0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=False, startangle=140)
plt.title('Worst Crime Display of DNA-based exoneration cases')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### all cases

# %%
df['Worst Crime Display'].value_counts().head()
# Out:
# Murder                     802
# Sexual Assault             302
# Drug Possession or Sale    241
# Child Sex Abuse            236
# Robbery                    106
# Name: Worst Crime Display, dtype: int64

# %%
df['Worst Crime Display'].value_counts().sum()
# Out:
# 2060

# %%
df['Worst Crime Display'].value_counts().head(5).sum()
# Out:
# 1687

# %%
2060-1687
# Out:
# 373

# %%
df['Worst Crime Display'].value_counts().sort_values(ascending=True).tail(5).plot(kind='barh')

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = 'Sexual Assault', 'Murder', 'Child Sex Abuse', 'Robbery', 'Kidnapping', 'other'
sizes = [802, 302, 241, 236, 106, 373]
colors = ['#437F7B', '#4F6289', '#CEAC6D', '#CE976D', '#82491D', '#A9853F']
explode = (0.1, 0, 0, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=False, startangle=140)
plt.title('Worst Crime Display of all exoneration cases')
plt.axis('equal')
plt.show()

# %%
df_proDNA['Worst Crime Display'].value_counts().sort_values(ascending=True).tail(10).plot(kind='barh')
