# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] =42
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches

# %%
df_mus = pd.read_csv("MusicGenrePreference.csv")
df_mus.head()
# Out:
#    user.id                     genre        date                score
# 0       73  indie / alternative rock  2008-09-22                  NaN
# 1       55  indie / alternative rock  2008-09-19                  NaN
# 2       36  indie / alternative rock  2008-09-19  2 Moderate Interest
# 3       39  indie / alternative rock  2008-09-18                  NaN
# 4       37  indie / alternative rock  2008-09-16      3 High Interest

# %%
df_pol = pd.read_csv("Politics.csv")
df_pol.head()
# Out:
#    user_id interested_in_politics preferred_party  \
# 0       55        Very interested     Independent
# 1       36    Slightly interested      Republican
# 2       39    Somewhat interested        Democrat
# 3       37  Not at all interested        Democrat
# 4       72        Very interested        Democrat
#
#                       likelihood_of_voting         voting_for_today  \
# 0                  I will most likely vote     Probably John McCain
# 1  I don't know whether or not I will vote   Definitely John McCain
# 2                                      NaN    Probably Barack Obama
# 3              I will most likely not vote    Probably Barack Obama
# 4                   I will definitely vote  Definitely Barack Obama
#
#     preferred_party_details liberal_or_conservative  survey.month  \
# 0          Republican Party   Slightly conservative       2008.09
# 1         Strong Republican            Conservative       2008.09
# ...

# %%
df = df_pol.merge(df_mus, left_on= 'user_id', right_on='user.id')
df.head()
# Out:
#    user_id interested_in_politics preferred_party     likelihood_of_voting  \
# 0       55        Very interested     Independent  I will most likely vote
# 1       55        Very interested     Independent  I will most likely vote
# 2       55        Very interested     Independent  I will most likely vote
# 3       55        Very interested     Independent  I will most likely vote
# 4       55        Very interested     Independent  I will most likely vote
#
#        voting_for_today preferred_party_details liberal_or_conservative  \
# 0  Probably John McCain        Republican Party   Slightly conservative
# 1  Probably John McCain        Republican Party   Slightly conservative
# 2  Probably John McCain        Republican Party   Slightly conservative
# 3  Probably John McCain        Republican Party   Slightly conservative
# 4  Probably John McCain        Republican Party   Slightly conservative
#
#    survey.month did_vote_in_election not_voted_preferred_candidate  \
# ...

# %%
popular = df.groupby('preferred_party')['genre'].value_counts()
popular.groupby(level=0).nlargest(3)
# Out:
# preferred_party          preferred_party          genre
# Democrat                 Democrat                 classic rock      416
#                                                   classical         416
#                                                   country / folk    416
# Independent              Independent              classic rock      219
#                                                   classical         219
#                                                   country / folk    219
# Member of another party  Member of another party  classic rock       21
#                                                   classical          21
#                                                   country / folk     21
# Republican               Republican               classic rock       43
#                                                   classical          43
#                                                   country / folk     43
# Name: genre, dtype: int64
