# %%
import pandas as pd
import geopandas as gpd

# %%
#http://openstreetmapdata.com/data
shapes = gpd.read_file("/Users/aspasiadaskalopoulou/Desktop/studio-projects/code/project5/water-polygons-split-4326/water_polygons.shp")
shapes.head()
# Out:
#    FID                                           geometry
# 0    0  POLYGON ((-180 -77.7492, -180 -44.9999, -134.9...
# 1    1  POLYGON ((-180 -90, -180 -77.7492, -179.99999 ...
# 2    2  POLYGON ((-180 -45.0001, -180 -39.3749, -177.1...
# 3    3  POLYGON ((-176.484275 -43.94882967520659, -176...
# 4    4  POLYGON ((-176.484275 -43.94403827954635, -176...

# %%
#http://www.marineregions.org/sources.php#marbound
shapes1 = gpd.read_file("/Users/aspasiadaskalopoulou/Desktop/studio-projects/code/project5/World_EEZ_v9_20161021/eez_boundaries.shp")
shapes1.head()
# Out:
#      Doc_date                              EEZ1  \
# 0  18/12/1992  Albanian Exclusive Economic Zone
# 1  08/10/1990   Belgian Exclusive Economic Zone
# 2  08/10/1990   Belgian Exclusive Economic Zone
# 3  18/12/1996   Belgian Exclusive Economic Zone
# 4  18/12/1996   Belgian Exclusive Economic Zone
#
#                               EEZ2 Joint_reg  Line_ID              Line_name  \
# 0  Italian Exclusive Economic Zone                123        Albania - Italy
# 1   French Exclusive Economic Zone                124       Belgium - France
# 2   French Exclusive Economic Zone                125       Belgium - France
# 3    Dutch Exclusive Economic Zone                126  Belgium - Netherlands
# 4    Dutch Exclusive Economic Zone                127  Belgium - Netherlands
#
#   Line_type  MRGID_EEZ1  MRGID_EEZ2  MRGID_JReg  \
# 0    Treaty        5670        5682           0
# 1    Treaty        3293        5677           0
# 2    Treaty        3293        5677           0
# ...

# %%
shapes2 = gpd.read_file("/Users/aspasiadaskalopoulou/Desktop/studio-projects/code/project5/World_EEZ_v9_20161021/eez.shp")
shapes2.head()
# Out:
#        Area_km2                                            GeoName ISO_Ter1  \
# 0  4.058442e+05             American Samoa Exclusive Economic Zone      ASM
# 1  4.460053e+05                  Ascension Exclusive Economic Zone      ASC
# 2  1.969507e+06               Cook Islands Exclusive Economic Zone      COK
# 3  5.499317e+05  Disputed area Falkland Islands Exclusive Econo...      FLK
# 4  4.766884e+06          French Polynesian Exclusive Economic Zone      PYF
#
#   ISO_Ter2 ISO_Ter3  MRGID  MRGID_EEZ  MRGID_Sov1  MRGID_Sov2  MRGID_Sov3  \
# 0                     8444       8444        2204           0           0
# 1                     8379       8379        2208           0           0
# 2                     8446       8446        2227           0           0
# 3      ARG            8389       8389        2208        2149           0
# 4                     8440       8440          17           0           0
#
# ...

# %%
shapes2.shape
# Out:
# (281, 24)

# %%
pd.set_option('display.max_rows', 300)
shapes2['ISO_Ter1']
# Out:
# 0      ASM
# 1      ASC
# 2      COK
# 3      FLK
# 4      PYF
# 5      PCN
# 6      SHN
# 7      WSM
# 8      TON
# 9      TAA
# 10     CHL
# 11     NIU
# 12     SGS
# 13     URY
# 14     PER
# 15     URY
# 16     ATF
# 17     IOT
# 18     CXR
# 19     CCK
# 20     COM
# 21     ATF
# 22     MYT
# 23     REU
# 24     HMD
# 25     ATF
# 26     MDG
# 27     ZAF
# 28     NCL
# 29     NFK
# 30     MUS
# 31     REU
# 32     VUT
# 33     NAM
# 34     TLS
# 35     COG
# 36     AGO
# 37     MOZ
# 38     KEN
# 39     TLS
# 40     AUS
# 41     PNG
# 42     ZAF
# 43     TZA
# 44     SLB
# 45     AIA
# 46     ATG
# 47     ABW
# 48     PRT
# 49     BHS
# 50     BRB
# 51     MEX
# 52     BMU
# 53     BES
# 54     VGB
# 55     CPV
# 56     ESP
# 57     CYM
# 58     CPT
# 59     PAN
# 60     CRI
# 61     CUW
# 62     DMA
# 63     DOM
# 64     GTM
# 65     FRO
# 66     GMB
# 67     GIB
# 68     GRD
# 69     GLP
# 70     SLE
# 71     ISL
# 72     JAM
# 73     PRT
# 74     MRT
# 75     MSR
# ...

# %%
shapes2.to_csv("shapes2.csv")

# %%
shapes2[142:143]
# Out:
#          Area_km2                          GeoName ISO_Ter1 ISO_Ter2 ISO_Ter3  \
# 142  262134.62716  Turkish Exclusive Economic Zone      TUR
#
#      MRGID  MRGID_EEZ  MRGID_Sov1  MRGID_Sov2  MRGID_Sov3    ...      \
# 142   5697       5697        2213           0           0    ...
#
#      PolygonID  Sovereign1  Sovereign2 Sovereign3  Territory1 Territory2  \
# 142        149      Turkey                             Turkey
#
#     Territory3  \
# 142
#
# ...

# %%
shapes2['GeoName']
# Out:
# 0                                                      American Samoa Exclusive Economic Zone
# 1                                                           Ascension Exclusive Economic Zone
# 2                                                        Cook Islands Exclusive Economic Zone
# 3                      Disputed area Falkland Islands Exclusive Economic Zone: UK / Argentina
# 4                                                   French Polynesian Exclusive Economic Zone
# 5                                                    Pitcairn Islands Exclusive Economic Zone
# 6                                                          St. Helena Exclusive Economic Zone
# 7                                                              Samoan Exclusive Economic Zone
# 8                                                              Tongan Exclusive Economic Zone
# 9                                                    Tristan Da Cunha Exclusive Economic Zone
# ...
