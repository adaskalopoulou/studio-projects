# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] =42
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches

# %%
df_colors = pd.read_csv("colors.csv")
df_colors.head()
# Out:
#    id            name     rgb is_trans
# 0  -1         Unknown  0033B2        f
# 1   0           Black  05131D        f
# 2   1            Blue  0055BF        f
# 3   2           Green  237841        f
# 4   3  Dark Turquoise  008F9B        f

# %%
df_parts = pd.read_csv("parts.csv")
df_parts.head()
# Out:
#   part_num                                               name  part_cat_id
# 0   0687b1                        Set 0687 Activity Booklet 1           17
# 1     0901  Baseplate 16 x 30 with Set 080 Yellow House Print            1
# 2     0902  Baseplate 16 x 24 with Set 080 Small White Hou...            1
# 3     0903     Baseplate 16 x 24 with Set 080 Red House Print            1
# 4     0904  Baseplate 16 x 24 with Set 080 Large White Hou...            1

# %%
df_partcat = pd.read_csv("part_categories.csv")
df_partcat.head()
# Out:
#    id                     name
# 0   1               Baseplates
# 1   2           Bricks Printed
# 2   3            Bricks Sloped
# 3   4  Duplo, Quatro and Primo
# 4   5           Bricks Special

# %%
df_sets = pd.read_csv("sets.csv")
df_sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0    00-1             Weetabix Castle  1970       414        471
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
df_themes = pd.read_csv("themes.csv")
df_themes.head()
# Out:
#    id            name  parent_id
# 0   1         Technic        NaN
# 1   2  Arctic Technic        1.0
# 2   3     Competition        1.0
# 3   4  Expert Builder        1.0
# 4   5           Model        1.0

# %%
df_inv = pd.read_csv("inventories.csv")
df_inv.head()
# Out:
#    id  version set_num
# 0   1        1  7922-1
# 1   3        1  3931-1
# 2   4        1  6942-1
# 3  15        1  5158-1
# 4  16        1   903-1

# %%
df_invparts = pd.read_csv("inventory_parts.csv")
df_invparts.head()
# Out:
#    inventory_id     part_num  color_id  quantity is_spare
# 0             1     48379c01        72         1        f
# 1             1        48395         7         1        f
# 2             1     mcsport6        25         1        f
# 3             1       paddle         0         1        f
# 4             3  11816pr0005        78         1        f

# %%
df_invsets = pd.read_csv("inventory_sets.csv")
df_invsets.head()
# Out:
#    inventory_id  set_num  quantity
# 0            35  75911-1         1
# 1            35  75912-1         1
# 2            39  75048-1         1
# 3            39  75053-1         1
# 4            50   4515-1         1

# %% [markdown]
# ## Colors introduced every year

# %%
df_par_color = df_invparts.merge(df_colors, left_on='color_id', right_on='id', how='outer')

# %%
df_par_color
# Out:
#         inventory_id  part_num  color_id  quantity is_spare    id  \
# 0                1.0  48379c01      72.0       1.0        f    72
# 1               22.0     15573      72.0       1.0        f    72
# 2               22.0      2654      72.0       4.0        f    72
# 3               22.0     3070b      72.0       1.0        f    72
# 4               22.0     3070b      72.0       1.0        t    72
# 5               22.0      3666      72.0       1.0        f    72
# 6               22.0     4081b      72.0       1.0        f    72
# 7               22.0     41769      72.0       4.0        f    72
# 8               22.0     41770      72.0       4.0        f    72
# 9               22.0     43719      72.0       1.0        f    72
# 10              22.0     85984      72.0       3.0        f    72
# 11              28.0      2431      72.0       1.0        f    72
# 12              28.0      2460      72.0       1.0        f    72
# 13              28.0      2569      72.0       1.0        t    72
# 14              28.0      2569      72.0       2.0        f    72
# 15              28.0     30162      72.0       3.0        f    72
# 16              28.0      3020      72.0       1.0        f    72
# 17              28.0      3023      72.0       2.0        f    72
# 18              28.0    30361c      72.0       1.0        f    72
# 19              28.0     30592      72.0       1.0        f    72
# 20              28.0      4162      72.0       2.0        f    72
# 21              28.0     54101      72.0       1.0        f    72
# 22              28.0      6553      72.0       1.0        f    72
# 23              28.0    970c00      72.0       1.0        f    72
# 24              30.0      3937      72.0       1.0        f    72
# 25              32.0      3004      72.0       1.0        f    72
# 26              32.0      3660      72.0       1.0        f    72
# 27              37.0     32002      72.0       1.0        t    72
# 28              37.0     32002      72.0       1.0        f    72
# 29              37.0     32199      72.0       1.0        f    72
# ...              ...       ...       ...       ...      ...   ...
# 580225       14512.0   kraata3     183.0       1.0        f   183
# 580226       14512.0   kraata4     183.0       1.0        f   183
# 580227       14512.0   kraata5     183.0       1.0        f   183
# 580228       14512.0   kraata6     183.0       1.0        f   183
# 580229       15111.0     44138     183.0       2.0        f   183
# 580230       15111.0     44140     183.0       1.0        f   183
# 580231       15111.0     44807     183.0       1.0        f   183
# 580232       15200.0     44138     183.0       2.0        f   183
# 580233       15200.0     44140     183.0       1.0        f   183
# 580234       15200.0     44807     183.0       1.0        f   183
# 580235        8962.0     89917     133.0       1.0        f   133
# 580236       11058.0     89917     133.0       1.0        f   133
# 580237       11058.0     89918     133.0       1.0        f   133
# 580238       12521.0     89918     133.0       1.0        f   133
# 580239       15876.0     89917     133.0       1.0        f   133
# 580240        9555.0     30385      62.0       1.0        f    62
# 580241       15287.0     30385      62.0       1.0        f    62
# 580242       10117.0      4131     351.0       3.0        f   351
# 580243       10117.0      4133     351.0       6.0        f   351
# 580244       10117.0      4728     351.0       3.0        f   351
# 580245       10904.0      4131     351.0       2.0        f   351
# 580246       10904.0      4133     351.0       2.0        f   351
# 580247       10904.0      4728     351.0       4.0        f   351
# 580248       12090.0      6180    1001.0       1.0        f  1001
# 580249       13140.0      3001    1001.0       1.0        f  1001
# 580250       16084.0     51686    1006.0       2.0        f  1006
# 580251           NaN       NaN       NaN       NaN      NaN    32
# 580252           NaN       NaN       NaN       NaN      NaN  1004
# 580253           NaN       NaN       NaN       NaN      NaN  1005
# 580254           NaN       NaN       NaN       NaN      NaN  1007
#
#                                 name     rgb is_trans
# 0                   Dark Bluish Gray  6C6E68        f
# 1                   Dark Bluish Gray  6C6E68        f
# 2                   Dark Bluish Gray  6C6E68        f
# 3                   Dark Bluish Gray  6C6E68        f
# 4                   Dark Bluish Gray  6C6E68        f
# 5                   Dark Bluish Gray  6C6E68        f
# 6                   Dark Bluish Gray  6C6E68        f
# 7                   Dark Bluish Gray  6C6E68        f
# 8                   Dark Bluish Gray  6C6E68        f
# 9                   Dark Bluish Gray  6C6E68        f
# 10                  Dark Bluish Gray  6C6E68        f
# 11                  Dark Bluish Gray  6C6E68        f
# 12                  Dark Bluish Gray  6C6E68        f
# 13                  Dark Bluish Gray  6C6E68        f
# 14                  Dark Bluish Gray  6C6E68        f
# 15                  Dark Bluish Gray  6C6E68        f
# 16                  Dark Bluish Gray  6C6E68        f
# 17                  Dark Bluish Gray  6C6E68        f
# 18                  Dark Bluish Gray  6C6E68        f
# 19                  Dark Bluish Gray  6C6E68        f
# 20                  Dark Bluish Gray  6C6E68        f
# 21                  Dark Bluish Gray  6C6E68        f
# 22                  Dark Bluish Gray  6C6E68        f
# 23                  Dark Bluish Gray  6C6E68        f
# 24                  Dark Bluish Gray  6C6E68        f
# 25                  Dark Bluish Gray  6C6E68        f
# 26                  Dark Bluish Gray  6C6E68        f
# 27                  Dark Bluish Gray  6C6E68        f
# 28                  Dark Bluish Gray  6C6E68        f
# 29                  Dark Bluish Gray  6C6E68        f
# ...                              ...     ...      ...
# 580225                   Pearl White  F2F3F2        f
# 580226                   Pearl White  F2F3F2        f
# 580227                   Pearl White  F2F3F2        f
# 580228                   Pearl White  F2F3F2        f
# 580229                   Pearl White  F2F3F2        f
# 580230                   Pearl White  F2F3F2        f
# 580231                   Pearl White  F2F3F2        f
# 580232                   Pearl White  F2F3F2        f
# 580233                   Pearl White  F2F3F2        f
# 580234                   Pearl White  F2F3F2        f
# 580235            Speckle Black-Gold  000000        f
# 580236            Speckle Black-Gold  000000        f
# 580237            Speckle Black-Gold  000000        f
# 580238            Speckle Black-Gold  000000        f
# 580239            Speckle Black-Gold  000000        f
# 580240                  Chrome Green  3CB371        f
# 580241                  Chrome Green  3CB371        f
# 580242              Medium Dark Pink  F785B1        f
# 580243              Medium Dark Pink  F785B1        f
# 580244              Medium Dark Pink  F785B1        f
# 580245              Medium Dark Pink  F785B1        f
# 580246              Medium Dark Pink  F785B1        f
# 580247              Medium Dark Pink  F785B1        f
# 580248                 Medium Violet  9391E4        f
# 580249                 Medium Violet  9391E4        f
# 580250        Trans Light Royal Blue  B4D4F7        t
# 580251           Trans-Black IR Lens  635F52        t
# 580252  Trans Flame Yellowish Orange  FCB76D        t
# 580253             Trans Fire Yellow  FBE890        t
# 580254                 Reddish Lilac  8E5597        f
#
# [580255 rows x 9 columns]

# %%
df_sets

# %% [markdown]
# ## Storyline including the revenues of the company

# %%
df_sets.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0    00-1             Weetabix Castle  1970       414        471
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
df_sets.shape
# Out:
# (11673, 5)

# %%
df_sets.dtypes
# Out:
# set_num      object
# name         object
# year          int64
# theme_id      int64
# num_parts     int64
# dtype: object

# %%
df_sets['year'].value_counts().sort_index().plot(kind='barh', figsize=(40,40))
plt.savefig("set_years.pdf")
